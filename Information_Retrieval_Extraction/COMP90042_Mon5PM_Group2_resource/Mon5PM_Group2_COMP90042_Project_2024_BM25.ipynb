# %% [markdown]
# # 2024 COMP90042 Project

# %% [markdown]
# # Readme
#
# #### **Document Retreival using BM25 Model**:
#
# In this notebook, we train our custom implementation of a BM25 retreiver model on a corpus consisting of all sentences from the knowledge source. Then we evaluate the performance of this trained BM25 model on both the training and validation set claims
#
# *** **PLEASE NOTE**: The BM25 model implementation is contained in a separate python script called: `BM25.py`. We are importing the `BM25` class from this script. We also import helper function that we implemented for pre-processing/cleaning our data from the python script called `utils.py`.

# %%
# %load_ext autoreload
# %autoreload 2

# install required packages
# !pip install unidecode
# !python -m nltk.downloader stopwords

from utils import *
from BM25 import *
import pickle 
import numpy as np

# %% [markdown]
# # 1.DataSet Processing

# %% [markdown]
# #### Load the Claims Dataset with Knowledge Source and Clean the Text

# %%
# load dataset and prepare corpus
knowledge_source, train_data, val_data = load_dataset()      
print(f"Number of evidence passages: {len(knowledge_source)}")
print(f"Number of training instances: {len(train_data)}")  
print(f"Number of validation instances: {len(val_data)}")


# clean all senteneces in the dataset (this involves converting from unicode to asc-ii, removing URLS, removing repeating non-alphanumeric characters, etc. Just a bunch of thing that are most likely will not be useful for claim classification task)
cleaner = SentenceCleaner()
knowledge_source, train_data, val_data = cleaner.clean_dataset(knowledge_source, train_data, val_data)
print(f"\nNumber of evidence passages after cleaning: {len(knowledge_source)}")
print(f"Number of training instances after cleaning: {len(train_data)}")  
print(f"Number of validation instances after cleaning: {len(val_data)}")

# dictionary for mapping integer to document id 
int2docID = {i:evidence_id for i,evidence_id in enumerate(list(knowledge_source.keys()))}
claim_ids = [claim_id for claim_id in train_data.keys()]
# Out:
# Number of evidence passages: 1208827
# Number of training instances: 1228
# Number of validation instances: 154
#
# Number of evidence passages after cleaning: 1206800
# Number of training instances after cleaning: 1228
# Number of validation instances after cleaning: 154

# %% [markdown]
# # 2. Model Implementation

# %% [markdown]
# #### Instantiate and train BM25 retreiver on the Knowledge Source corpus.

# %%
# instantiate and train a BM25 retreiver
retriever = BM25_retriever(b=0.3, k=0.5, remove_stopwords=True, apply_stemming=True) # set options for stopword removal and stemming
retriever.train(knowledge_source.values())
# Out:
# Tokenizing documents...
#   0%|          | 0/1206800 [00:00<?, ?it/s]
# 100%|██████████| 1206800/1206800 [02:17<00:00, 8763.01it/s]
# Computing TF...
# 100%|██████████| 1206800/1206800 [00:39<00:00, 30481.31it/s]
# Computing TFIDF and creating inverted index...
# 100%|██████████| 501827/501827 [00:30<00:00, 16725.97it/s]
# Computing TFIDF vector norms...
# 100%|██████████| 1206800/1206800 [00:32<00:00, 36743.99it/s]

# %% [markdown]
# #### Save trained BM25 retriever to file

# %%
# Save the trained retreiver object to the pickle file
with open("bm25_b=0.3_k=0.5.pkl", "wb") as file:
    pickle.dump(retriever, file)
    print("Saved the trained BM25 retriever object to the pickle file")

# Load the trained retriever object from the pickle file
#with open("bm25_b=0.3_k=0.5.pkl", "rb") as file:
#    retriever = pickle.load(file)

# %% [markdown]
# # 3.Testing and Evaluation

# %% [markdown]
# #### Run some document retreival tests to see what kind of evidence is being retreived for some given claims.

# %%
# evaluate retreival results for a given claim text
def claim_retreive_eval(claim, k=5):
    print(f"Claim: {claim['claim_text']}")
    # get top k relevant evidence passages and their scores
    topk_ev_indices, topk_scores = retriever.retrieve_docs(query=claim['claim_text'], topk=k)
    # convert indices to document ids
    topk_ev_ids = [int2docID[i] for i in topk_ev_indices]
    # get the gold evidence ids
    gold_ev_ids = claim['evidences']
    # compute precision, recall, and F1
    intersection = set(topk_ev_ids).intersection(gold_ev_ids)
    precision = len(intersection) / len(topk_ev_ids)
    recall = len(intersection) / len(gold_ev_ids)
    f1 = (2*precision*recall/(precision + recall)) if (precision + recall) > 0 else 0 

    print(f"\nGold evidence passages: {gold_ev_ids}")
    for ev in gold_ev_ids:
        print(f"{ev} --> {knowledge_source[ev]}")
    
    print(f"\nTop {k} retrieved evidence passages: {topk_ev_ids}")
    for ev in topk_ev_ids:
        print(f"{ev} --> {knowledge_source[ev]}")

    print(f"\nMatching evidence passages: {intersection}")

    
    print(f"Precision: {precision}, Recall: {recall}, F1: {f1}")

    return precision, recall, f1

# %%
# pick a random claim
claim = val_data['claim-2583'] #train_data[random.choice(claim_ids)]

# evaluate the retreiver for this claim
claim_retreive_eval(claim, k=10000)
# Out:
# Claim: "Each unit of CO2 you put into the atmosphere has less and less of a warming impact.
#
# Gold evidence passages: ['evidence-827004', 'evidence-677057', 'evidence-1169593', 'evidence-1099186', 'evidence-178206']
# evidence-827004 --> The international community began the long process towards building effective international and domestic measures to tackle GHG emissions (carbon dioxide, methane, nitrous oxide, hydroflurocarbons, perfluorocarbons, sulphur hexafluoride) in response to the increasing assertions that global warming is happening due to man-made emissions and the uncertainty over its likely consequences.
# evidence-677057 --> This creates air pollution, including nitrous oxides and particulates, and is a significant contributor to global warming through emission of carbon dioxide, for which transport is the fastest-growing emission sector.
# evidence-1169593 --> Still the global warming potential of the landfill gas emitted to atmosphere is significant.
# evidence-1099186 --> The Kyoto Protocol is an international treaty which extends the 1992 United Nations Framework Convention on Climate Change (UNFCCC) that commits state parties to reduce greenhouse gas emissions, based on the scientific consensus that (part one) global warming is occurring and (part two) it is extremely likely that human-made CO2 emissions have predominantly caused it.
# evidence-178206 --> This additional CO2 led to a projected increase in warming of between 0.1 and 1.5 degC.
#
# Top 10000 retrieved evidence passages: ['evidence-954785', 'evidence-376130', 'evidence-853518', 'evidence-1184683', 'evidence-556321', 'evidence-1167485', 'evidence-247680', 'evidence-198465', 'evidence-143211', 'evidence-366724', 'evidence-393440', 'evidence-458949', 'evidence-80073', 'evidence-633435', 'evidence-587520', 'evidence-637727', 'evidence-1151331', 'evidence-878919', 'evidence-752194', 'evidence-579096', 'evidence-581392', 'evidence-676996', 'evidence-7241', 'evidence-484732', 'evidence-913997', 'evidence-46484', 'evidence-838690', 'evidence-655299', 'evidence-1162884', 'evidence-244364', 'evidence-340620', 'evidence-885868', 'evidence-1040492', 'evidence-1167035', 'evidence-332433', 'evidence-954205', 'evidence-605131', 'evidence-899867', 'evidence-101852', 'evidence-762271', 'evidence-694696', 'evidence-787368', 'evidence-590996', 'evidence-449405', 'evidence-1088935', 'evidence-469471', 'evidence-591671', 'evidence-677657', 'evidence-764532', 'evidence-215395', 'evidence-128487', 'evidence-741334', 'evidence-1110617', 'evidence-446526', 'evidence-219708', 'evidence-994459', 'evidence-667609', 'evidence-344948', 'evidence-377692', 'evidence-479858', 'evidence-698359', 'evidence-746634', 'evidence-260626', 'evidence-489048', 'evidence-110906', 'evidence-842871', 'evidence-157032', 'evidence-286316', 'evidence-97203', 'evidence-558429', 'evidence-917555', 'evidence-1004947', 'evidence-624190', 'evidence-41739', 'evidence-474441', 'evidence-5536', 'evidence-1016493', 'evidence-1160715', 'evidence-864498', 'evidence-1168721', 'evidence-141876', 'evidence-92736', 'evidence-82770', 'evidence-192767', 'evidence-518909', 'evidence-171051', 'evidence-870300', 'evidence-70581', 'evidence-406857', 'evidence-358423', 'evidence-1064368', 'evidence-454638', 'evidence-1154460', 'evidence-876434', 'evidence-409121', 'evidence-558962', 'evidence-455608', 'evidence-590954', 'evidence-66248', 'evidence-782135', 'evidence-188771', 'evidence-918729', 'evidence-395329', 'evidence-798477', 'evidence-882352', 'evidence-405429', 'evidence-914790', 'evidence-720941', 'evidence-957011', 'evidence-1169695', 'evidence-332220', 'evidence-1207609', 'evidence-159273', 'evidence-209327', 'evidence-934569', 'evidence-716853', 'evidence-618034', 'evidence-623096', 'evidence-170578', 'evidence-126506', 'evidence-393810', 'evidence-173055', 'evidence-869417', 'evidence-515350', 'evidence-333326', 'evidence-1045141', 'evidence-1205904', 'evidence-796352', 'evidence-465681', 'evidence-613425', 'evidence-345720', 'evidence-1132748', 'evidence-967103', 'evidence-1123320', 'evidence-457468', 'evidence-914252', 'evidence-322950', 'evidence-1004560', 'evidence-119499', 'evidence-867016', 'evidence-1024321', 'evidence-176925', 'evidence-710096', 'evidence-780720', 'evidence-406602', 'evidence-1107908', 'evidence-1022804', 'evidence-992879', 'evidence-624848', 'evidence-788350', 'evidence-791691', 'evidence-1172346', 'evidence-576812', 'evidence-1167189', 'evidence-648412', 'evidence-493959', 'evidence-871145', 'evidence-931324', 'evidence-963725', 'evidence-810834', 'evidence-1151465', 'evidence-96726', 'evidence-413206', 'evidence-1169712', 'evidence-849752', 'evidence-729978', 'evidence-1171675', 'evidence-395860', 'evidence-178206', 'evidence-1047277', 'evidence-695386', 'evidence-793052', 'evidence-736918', 'evidence-1093172', 'evidence-488045', 'evidence-31319', 'evidence-907202', 'evidence-325599', 'evidence-1196078', 'evidence-700207', 'evidence-1110676', 'evidence-646413', 'evidence-554833', 'evidence-521113', 'evidence-161480', 'evidence-364314', 'evidence-1080820', 'evidence-230638', 'evidence-6872', 'evidence-445179', 'evidence-1043831', 'evidence-439291', 'evidence-690131', 'evidence-937329', 'evidence-782882', 'evidence-700429', 'evidence-428072', 'evidence-279726', 'evidence-1165791', 'evidence-769182', 'evidence-67424', 'evidence-736930', 'evidence-705411', 'evidence-1185085', 'evidence-1083682', 'evidence-185095', 'evidence-949442', 'evide ...
# evidence-954785 --> less than 14% of the observed global warming.
# evidence-376130 --> CO is 25 times less potent than methane when emitted into the atmosphere with regards to global warming.
# evidence-853518 --> Primary energy use was less in the United States than in China in 2009.
# evidence-1184683 --> It has been known since 1872 that as we emit more and more carbon dioxide into our atmosphere, each increment results in less and less warming.
# evidence-556321 --> He competed until 1980 but with less success.
# evidence-1167485 --> Less direct geological evidence indicates that CO2 values have not been this high for millions of years.
# evidence-247680 --> "How do we know more CO2 is causing warming?".
# evidence-198465 --> In other words, the first changes produce the most warming, and subsequent ones produce a bit less, and so on.
# evidence-143211 --> It originally consisted of less than 100 members.
# evidence-366724 --> It is also a less common name of German origins.
# evidence-393440 -->  It remains popular in Continental Europe, but less so in the United Kingdom.
# evidence-458949 --> At the 2011 Census the population was less than 100.
# evidence-80073 --> The population as of the 2011 census was less than 100.
# evidence-633435 --> It is known less often on other continents.
# evidence-587520 --> If you use less than your Entitlement of units, you can sell your surplus.
# evidence-637727 --> It does best in warm areas and tends to be much less effective in areas that get cold.
# evidence-1151331 --> The school 's capacity is now less than 600.
# evidence-878919 --> falling to less than 100 at the 2011 Census.
# evidence-752194 --> Other scientists were less enthusiastic.
# evidence-579096 --> This goal was reached in less than five days.
# evidence-581392 --> It generally received less attention from writers than
# evidence-676996 --> Today this practice has become less common.
# evidence-7241 --> Self/less was released on July 10, 2015.
# evidence-484732 --> Atmosphere (unit), a unit of pressure
# evidence-913997 --> Less energy reaches the upper atmosphere, which is therefore cooler because of this absorption.
# evidence-46484 --> The population as of the 2011 census remained less than 100.
# evidence-838690 --> The bank failed less than four years later.
# evidence-655299 --> There is less evidence that precipitation is changing.
# evidence-1162884 --> Larger asteroids are less common.
# evidence-244364 --> The population measured at the 2011 Census was less than 100.
# evidence-340620 --> The new show would last for less than half a season.
# evidence-885868 --> First by the coral cover, the more coral that is covering the ground the less of an impact bleaching had.
# evidence-1040492 --> The population taken at the 2011 Census was less than 100.
# evidence-1167035 --> The population as taken at the 2011 Census was less than 100.
# evidence-332433 --> He garnered less than 2% of the city's vote.
# evidence-954205 --> With increasing awareness about global warming, the question of peak oil has become less relevant.
# evidence-605131 --> He was also a competent artist in oils but is less known in this field.
# evidence-899867 --> A follow-up convention was held in 1999, but this was less successful.
# evidence-101852 --> This club flourished for less than a decade.
# evidence-762271 --> It is less than an hour 's drive from Adelaide.
# evidence-694696 --> They are run much less frequently in Britain.
# evidence-787368 --> This region receives less rainfall than the others.
# evidence-590996 --> It is estimated that less than 100 pairs remain.
# evidence-449405 --> It has since then sold less than 5,000 copies.
# evidence-1088935 --> This impact is reduced by not only consuming less but by also making the full cycle of production, use and disposal more sustainable.
# evidence-469471 --> It includes both formal stratigraphic unit names and less formal designations.
# evidence-591671 --> significantly smaller probability than less
# evidence-677657 --> Even for the less strict goal of 2 degC  warming, carbon capture is needed.
# evidence-764532 --> The consequence of this will be further climate warming which may lead to even less DMS production (and further climate warming).
# evidence-215395 --> "Eat less meat to avoid dangerous global warming, scientists say".
# evidence-128487 --> However, they generally had less creative control than the producer.
# evidence-741334 --> In 2013 he found less success, winning just one game in the championship.
# evidence-1110617 --> It is based on the novel of the same name by Doris Lessing.
# evidence-446526 --> The majority of Greenland, however, is less than in elevation.
# evidence-219708 --> In 2012, NASA scientists reported that to stop global warming atmospheric CO content would have to be reduced to 350 ppm or less, assuming all other climate forcings were fixed.
# evidence-994459 --> The village line in the remaining three directions are less distinct.
# evidence-667609 --> While doing so, the sustainable yield may be much less.
# evidence-344948 --> In the United States a month worth of medication is generally less than 25 USD.
# evidence-377692 --> In some states of the United States, much of the investment in a home-mounted system may be lost if the home-owner moves and the buyer puts less value on the system than the seller.
# evidence-479858 --> She plays guitar and, less frequently, piano.
# evidence-698359 --> Microscale meteorology is the study of atmospheric phenomena on a scale of about or less.
# evidence-746634 --> It brings rights and responsibilities, but less so than marriage.
# evidence-260626 --> Each molecule of methane would be converted into , which has a far smaller impact on climate (99% less).
# evidence-489048 --> New investigator, a designation for less experienced researchers
# evidence-110906 --> The urban heat island effect is very small, estimated to account for less than of warming per decade since 1900.
# evidence-842871 --> This resulted in their playing with more confidence, and less predictability.
# evidence-157032 --> It was relocated to a less visible area of a park.
# evidence-286316 --> Usually, a Sprint lasts for one month or less.
# evidence-97203 --> The further to the right, however, the less the two paintings resemble each other.
# evidence-558429 --> The listing was for an area of less than one acre with just one contributing building.
# evidence-917555 --> His first post was at St Andrew the Less, Cambridge.
# evidence-1004947 --> Student courts are a less-common feature of student governments.
# evidence-624190 --> While there is a greater amount of agreement over whether global warming exists, there is less agreement over the appropriate response.
# evidence-41739 --> This album was less successful with critics and in the charts than their previous albums.
# evidence-474441 --> Auguste was put more or less outside the protocol in the court life of Berlin, she ranked after all the princes and princesses of the royal family.
# evidence-5536 --> The town had a population of less than 3000 in the 2004 census.
# evidence-1016493 --> Their use has been extended to many other meanings, more or less analogous.
# evidence-1160715 --> Construction was completed in 1891 with less than $ 30,000.
# evidence-864498 --> The population as taken at the 2011 Census remained less than 100.
# evidence-1168721 --> There are thought to be less than 250 individuals in existence.
# evidence-141876 --> A less common kind of assembly practices marching.
# evidence-92736 --> He was killed in action less than three months before war 's end.
# evidence-82770 --> This place have less frequency of Government buses.
# evidence-192767 --> Adoption of girls, however, was much less common.
# evidence-518909 --> The player who offers less time wins auction.
# evidence-171051 --> His solo career was less successful than Bailey 's.
# evidence-870300 --> Obese subjects require less.
# evidence-70581 --> Many of the patrons were less than happy with this change.
# evidence-406857 --> Coal is the largest contributor to the human-made increase of CO2 in the atmosphere.
# evidence-358423 --> Others were less severely injured, but the paper did not name them.
# evidence-1064368 --> Global warming is the greatest cause of impact to the environment.
# evidence-454638 --> It was contested by 22 teams, three less than in the previous edition.
# evidence-1154460 --> St. Laurent had more hatred of communism, and less fear of the United States.
# evidence-876434 --> In 2015, electrical energy usage in the United States was 1.6% more than in 2005 and 1% less than the peak in 2007.
# evidence-409121 --> Less than 8 % of the Pakistani population speak English.
# evidence-558962 --> As of 2015 the cost for a typical course of treatment in the United States is less than 25 USD.
# evidence-455608 --> It was less successful in the UK, however, peaking at #47.
# evidence-590954 --> In retail, unit price is the price for a single unit of measure of a product sold in more or less than the single unit.
# evidence-66248 --> Nitrous oxide is known to have a greater impact on the atmosphere in relation to global warming, as it is also an ozone destroyer.
# evidence-782135 --> However, the House has other, less severe measures with which to discipline members.
# evidence-188771 --> Thus, today the store is no more and the label is less active than before.
# evidence-918729 --> After two years the level of protection decreases to less than 50 %.
# evidence-395329 --> Young birds are similar to females but have less black.
# evidence-798477 --> It seems that the contamination was less than feared.
# evidence-882352 --> In more recent times, she may be less, if at all, financially dependent on the man.
# evidence-405429 --> This type of honor is shared by less than 15,000 people.
# evidence-914790 --> He won re-election in 1962, defeating Frank W. Less.
# evidence-720941 --> Also, the dialect has less influence of Sanskrit.
# evidence-957011 --> 2002: Eric Roberts - "Less Than Perfect
# evidence-1169695 --> The song got airplay in the 1970s, but less after that.
# evidence-332220 --> The daily number of passengers was less than 500 in 2002.
# evidence-1207609 --> Contrails are visible line clouds that form in cold, humid atmospheres and are thought to have a global warming effect (though one less significant than either CO emissions or NO induced effects).
# evidence-159273 --> In general, RAD approaches to software development put less emphasis on planning and more emphasis on process.
# evidence-209327 --> Bob created the characters with less than three dollars.
# evidence-934569 --> It has more or less 350 physicians and surgeons.
# evidence-716853 --> Their colonies are generally small, consisting of less than 200 individuals.
# evidence-618034 --> Scale varies less than 2 % throughout the area covered.
# evidence-623096 --> They are both located on the same road less than two miles (3 km) apart.
# evidence-170578 --> Less than that amount would designate the rock as a granite.
# evidence-126506 --> Eventually they came to live on less than $ 5,000 per year.
# evidence-393810 --> Records of local or regional competitions are not included due to them being considered of less importance.
# evidence-173055 --> It decomposes and turns into carbon dioxide (CO2), which is released into the atmosphere.
# evidence-869417 --> For example, the United Arab Emirates ' native inhabitants make up less than 20 % of its overall population.
# evidence-515350 --> Price has been estimated to be less than 10,000 dollars.
# evidence-333326 --> Most of this thermal radiation is absorbed by the atmosphere and warms it.
# evidence-1045141 --> Concerns about the impact on agriculture led to the project 's being put on hold.
# evidence-1205904 --> As a partial solution, Lomborg presents fish farms, which cause a less disruptive impact on the world's oceans.
# evidence-796352 --> All regions are at risk of experiencing negative impacts, with low-latitude, less developed areas facing the greatest risk.
# evidence-465681 --> If the same diagnostic methods are used rates are more or less the same between countries.
# evidence-613425 --> However he died in office less than two months after his election to the House of Commons.
# evidence-345720 --> She resigned from the position in January 2007 after serving less than three weeks.
# evidence-1132748 --> Upon its release the film's reception was less than favorable.
# evidence-967103 --> are less likely to refinance into a new mortgage, and
# evidence-1123320 --> In fact, all other teams combined are still less than Mexico 's total.
# evidence-457468 --> Various factors impact the average state of the atmosphere at a particular location.
# evidence-914252 --> Use of the cemetery later was less orderly.
# evidence-322950 --> The heating of the atmosphere aloft also leads to a cooling of the surface, resulting in less evaporation of surface water.
# evidence-1004560 --> As of 2007, less than 50% of Haiti's forests remained.
# evidence-119499 --> These child actors are or were aged 17 or less at the time they started acting.
# evidence-867016 --> Countries whose oil production is 10% or less of their consumption.
# evidence-1024321 --> The development and scaling-up of clean technology, such as cement that produces less CO2, is critical to achieve sufficient emission reductions for the Paris agreement goals.
# evidence-176925 --> He was always willing to help out those with less money.
# evidence-710096 --> The demand factor is always less than or equal to one.
# evidence-780720 --> Housing further north and closer to University Avenue was less grand.
# evidence-406602 --> His health deteriorated after 1866, and he was less active.
# evidence-1107908 --> These actors were aged 17 or less at the time they started acting but are currently 18 or over.
# evidence-1022804 --> For a country of less than a million people, the find changes everything.
# evidence-992879 --> Its revenues cover less than one third of the printing cost.
# evidence-624848 --> All other radioisotopes have half-lives less than a day.
# evidence-788350 --> After World War II until the 1970s, the synagogue became less used.
# evidence-791691 --> Games are short, typically taking less than ten minutes to play.
# evidence-1172346 --> After less than one year in Sweden he came back to Czech Republic.
# evidence-576812 --> Greener procurement means choosing products and services that have less impact on the environment than their traditional counterparts.
# evidence-1167189 --> The season takes less than a year in order to change the league to become summer a league.
# evidence-648412 --> The name was first used by Christian Friedrich Lessing in 1831.
# evidence-493959 --> Despite the name, less than 20 people are skinned at the peak each year.
# evidence-871145 --> The mine is short and more or less contorted.
# evidence-931324 --> The less he or she knows the more likely a different term would be more fitting.
# evidence-963725 --> Lebanon also has a Jewish population, estimated at less than 100.
# evidence-810834 --> Non-CO emissions should decline in more or less similar ways.
# evidence-1151465 --> It is less well-preserved than the other two craters but of similar size.
# evidence-96726 --> This plant is less common than it was 100 to 150 years ago.
# evidence-413206 --> The album was followed by a non-album single, I 'm Less Here on Record Store Day 2014.
# evidence-1169712 --> It was watched 2.5 million times in less than a week following its release.
# evidence-849752 --> However, the rate of such malignancies is now known to be less than had been estimated.
# evidence-729978 --> It is a combination of the Cyrillic letters O and U or less frequently O and Y.
# evidence-1171675 --> Davis would be recalled less than a year into his next term.
# evidence-395860 --> There is a less common surname with the same pronunciation but different writing.
# evidence-178206 --> This additional CO2 led to a projected increase in warming of between 0.1 and 1.5 degC.
# evidence-1047277 --> 1 bonus point for losing by 7 points (or less).
# evidence-695386 --> 1 bonus point for losing by 7 points (or less).
# evidence-793052 --> The final Olympic rig was available less than a year before the Olympics.
# evidence-736918 --> The band themselves have been quite vocal in that they were less satisfied with the album.
# evidence-1093172 --> Slowing global warming requires a transition to a low-carbon economy, mainly by burning far less fossil fuel.
# evidence-488045 --> In less than two years, this choir has grown to over 70 members.
# evidence-31319 --> The team has enjoyed less success in continental and global competition.
# evidence-907202 --> It is calculated to be slightly less massive than the Sun.
# evidence-325599 --> Self-discharge decreases the shelf life of batteries and causes them to initially have less than a full charge when actually put to use.
# evidence-1196078 --> In twenty years, the population rose from less than 400 to over 6,000.
# evidence-700207 --> It is a short piece which can be played in less than a minute at concert speed.
# evidence-1110676 --> He announced his retirement from his playing career less than 48 hours later.
# evidence-646413 --> Despite being 84 years old, he found the man in less than a day.
# evidence-554833 --> The school faced financial problems, because less students came to the school.
# evidence-521113 --> The first unit was put into operation in 1964, and the second in 1984.
# evidence-161480 --> Types of impacts
# evidence-364314 --> It is a more positive and less radical variant of classical liberalism.
# evidence-1080820 --> However, the atmosphere is warming at lower altitudes while cooling higher up.
# evidence-230638 --> As climate warms, permafrost thaws, which results in a less stable mountain structure, and ultimately more slope failures.
# evidence-6872 --> Millions can be impacted.
# evidence-445179 --> Brazil's structure, legislation and settlement policies for arriving immigrants were much less organized than in Canada and the United States at the time.
# evidence-1043831 --> Less than ten years after its completion, it was destroyed by fire in 1837.
# evidence-439291 --> The game puts the player in the role of an immigrant in the United States.
# evidence-690131 --> Typical times can be found to be less than 16 milliseconds.
# evidence-937329 --> The coefficient of performance (COP), a more universal unit-less measure of efficiency, is discussed in the following section.
# evidence-782882 --> The heat is indirect, so there is less chance of burning.
# evidence-700429 --> They served less than two years on active duty, from 1893 to 1895.
# evidence-428072 --> This is in many places a common species, but elsewhere rather less common.
# evidence-279726 --> They are less expensive than soft sleepers.
# evidence-1165791 --> These two albums were much less successful internationally than her previous releases, but both charted in Japan.
# evidence-769182 --> Many discussions are based on projections and less with current migration data.
# evidence-67424 --> He wrote the music for no less than 55 films, including a large amount for television.
# evidence-736930 --> The list includes seven in Birmingham, five in Mobile, and two or less in any other city.
# evidence-705411 --> Manipulated elements located further away are used less frequently.
# evidence-1185085 --> The content is thus of less significance and not clearly accessible.
# evidence-1083682 --> It bore this name for less than a year before closing on March 31, 1915.
# evidence-185095 --> The Arctic sea ice covers less area in the summer than in the winter.
# evidence-949442 --> The Arctic sea ice covers less area in the summer than in the winter.
# evidence-535947 --> Sea level rise at specific locations may be more or less than the global average.
# evidence-484077 --> As a consequence, the length of the tower is slightly less at its base than at its top.
# evidence-498380 --> Current annual increase in atmospheric CO2 is approximately 4 gigatons of carbon.
# evidence-699771 --> Compared to other hydrocarbon fuels, methane produces less carbon dioxide for each unit of heat released.
# evidence-613526 --> 8% interest rate) is less than the return earned on the investment (i.e.
# evidence-157860 --> The CVF Declaration committed to achieve a concentration of no more than 350 ppm (parts per million) of carbon dioxide in the Earth's atmosphere and limit warming to 1.5 degrees Celsius (or less) above preindustrial levels.
# evidence-232254 --> Subsequent reports were to be issued not less than three and not more than seven years after the first periodic report.
# evidence-957565 --> The western part of the park is almost greeneries less.
# evidence-439272 --> It opened in May 2008 and closed less than nine months later, in February 2009.
# evidence-1140671 --> On the ground, the Hokies had even less success than they did in the air.
# evidence-633202 --> Cameron then became the minister to Russia, but was overseas for less than a year.
# evidence-185910 --> They may range in size from less than 1 mm to 3 mm.
# evidence-1070899 --> They are commonly found in literature, film, and video games, and are less common in other art forms.
# evidence-228505 --> The female version is deeper and less distinct than the male 's.
# evidence-664395 --> The rockets weighed less than and could be built for around $2000.
# evidence-47720 --> There are areas of more or less dark grey brown, including fringes.
# evidence-553073 --> The term in the United States is also used to refer to wives of governors and, less formally, to wives of college and university presidents.
# evidence-1203621 --> Another 11 % have lived at the same address for at least three years but less than five years.
# evidence-364767 --> It is expected that most ecosystems will be affected by higher atmospheric CO2 levels and higher global temperatures.
# evidence-124851 --> Compared to 2010, the nuclear industry produced 11% less electricity in 2012.
# evidence-641011 --> Worldwide oil discoveries have been less than annual production since 1980.
# evidence-1177428 --> temperature and atmosphere.
# evidence-743577 --> Infrared observation showed a bright spot where the impact took place, meaning the impact warmed up the lower atmosphere in the area near Jupiter's south pole.
# evidence-1006509 --> At the same time, objects that are less dense are displaced and move to the center.
# evidence-508603 --> He died less than two months after retiring from the Mayo Clinic.
# evidence-1073791 --> The word, and its shorter form beano, are fairly common in Britain, less known in the United States.
# evidence-889763 --> It grows up to 1.5 metre high, though usually rather less.
# evidence-576549 --> Since the impacts of climate change are generally not seen in the short-term, this means that policymakers have less incentive to act upon those potential outcomes.
# evidence-591764 --> It can also be produced by printing directly on the fabric, although this is less common.
# evidence-71840 --> The impact of global warming and human activities are presented in the Sahel.
# evidence-318651 --> The general trend is for higher standards of living to become less sustainable.
# evidence-283004 --> The implied viewing angle may be less than 18 degrees.
# evidence-630318 --> Impacts from second generation
# evidence-662931 --> "CO2 in the atmosphere just exceeded 415 parts per million for the first time in human history".
# evidence-221242 --> It has grown rapidly from nothing to 8 teams in less than one year.
# evidence-358167 --> As of 2009, United States per-capita energy use had declined to , 12% less than 2000, and in 2010, to levels not seen since the 1960s.
# evidence-820223 --> Then further dune building occurred so that breaks became less frequent.
# evidence-1203099 --> These all have a relatively low alcohol content, typically less than 15 %.
# evidence-402766 --> He realized that the cooler atmosphere would hold less water vapor (another greenhouse gas) and calculated the additional cooling effect.
# evidence-280403 --> Percentage of population aged less than 5 years old : 10.17 (2000)
# evidence-421202 --> Less than 1% of all species that have been described have been studied beyond simply noting their existence.
# evidence-127366 --> These locations have a higher potential for CSP than areas with less sun.
# evidence-364605 --> Methane in the atmosphere has a 100-year global warming potential of 34.
# evidence-502063 --> The flowers are about a centimeter long and less in width at the face.
# evidence-458040 --> It is possible that it was re-dedicated to James the Less in the Victorian era because of the smallness of the church.
# evidence-658569 --> These skull caps measure less than 5 cm (2 in) each.
# evidence-819035 --> It is, nevertheless, sited less than 2 km away on a hill facing it.
# evidence-570970 --> His debut less than two weeks later, against Ireland in the Intercontinental Cup.
# evidence-32852 --> In May 2019 the concentration of CO2 in the atmosphere reached 415 PPM.
# evidence-696683 --> Market mechanisms have less skewed distributional effects.
# evidence-1150308 --> The installation is usually less than 5 kW in a house or small business.
# evidence-618757 --> In the 16th century, no less than seven windmills were built on this hill.
# evidence-1155474 --> Other types leave less permanent records and may only be identified during excavation.
# evidence-733076 --> the removal of from the atmosphere.
# evidence-139356 --> There are 8 form groups for the 6th form students, with 20 students or less in each form.
# evidence-1149033 --> He suffered from ill health later in life and became less active in politics.
# evidence-359634 --> Finally, Canada exports less natural resources than Russia or Brazil.
# evidence-535034 --> He lost the 2010 election for Governor of Vermont by less than 5,000 votes.
# evidence-333958 --> peaks suffered substantially less disturbance than the mountains in the western or
# evidence-281428 --> In terms of actual production, in 2018 it was less than at any time since the industrial revolution.
# evidence-100018 --> The ice core data shows that temperature change causes the level of atmospheric CO2 to change - not the other way round.
# evidence-1101062 --> Younger people are "less resistant" to the idea of nuclear power in Australia.
# evidence-86354 --> It is less evident in ice cores from Antarctica and in South American indices.
# evidence-1188862 --> It takes less energy to recharge a battery than to produce a new one.
# evidence-1202938 --> Because apples are less dense than water, they will float at the surface.
# evidence-124353 --> The satellite has a mass of 100 kg, and is expected to operate for less than a year.
# evidence-809619 --> Generally clients are dealt with less severely, and usually only fined.
# evidence-406744 --> He was called to Denmark after less than two years and executed after a lengthy trial.
# evidence-1037920 --> The southern and western Highlands and the coastal region were less influential politically.
# evidence-1002848 --> The thickness of a third generation device is less than 1 um.
# evidence-138596 --> He had no less than 77 positions in boards of companies and non-governmental organizations.
# evidence-68802 --> In general, it takes far less energy to produce a unit mass of recycled materials than it does to make the same mass of virgin materials.
# evidence-334189 --> They were smaller and less capable than the preceding and were decommissioned in 1982.
# evidence-595830 --> It occurs as a few scattered populations with a total area of less than 50 ha.
# evidence-612395 --> (Where have you put the roses?)
# evidence-860186 --> Each episode of vertigo typically lasts less than one minute.
# evidence-378205 --> This method of softening price shocks is less useful in countries with much lower gas taxes, such as the United States.
# evidence-1043403 --> Because the bonded particles are now more stable and less mobile than before, they are called an island.
# evidence-1112112 --> With the ball, he bowled 30 wicket-less overs.
# evidence-170147 --> They are small in size and consume less power than computers of comparable capabilities.
# evidence-897120 --> algorithms have limited memory available to them (much less than the input
# evidence-355013 --> However, the effects of the compound on experimental animals appear less encouraging.
# evidence-80566 --> Featherweights had to be less than 56.7 kilograms.
# evidence-827488 --> In 2014, Finnish media reported a claim by two of the flight 's pilots that the Soviet Union had fired a missile at the aircraft, which exploded less than 30 seconds before impact.
# evidence-730564 --> With the ball, he bowled 18 wicket-less overs.
# evidence-682769 --> With the ball, he bowled 18 wicket-less overs.
# evidence-1141713 --> The horse version is less expensive but has a higher rate of side effects.
# evidence-699459 --> Women witnesses were given less weight than male ones in that era.
# evidence-1098715 --> Ortiz identifies himself less as a poet than a storyteller.
# evidence-244858 --> Baker also had several facilities in the actual state of Maine but these were less substantial.
# evidence-1019806 --> Developing countries have less awareness than developed, and Africa the least aware.
# evidence-788421 --> They were moved to the Neosho Valley where they lived for less than 30 years.
# evidence-482673 --> The hydrochlorofluorocarbons (HCFCs) are less stable in the lower atmosphere, enabling them to break down before reaching the ozone layer.
# evidence-358623 --> All the texts are 10,000 words or less and sentences are kept short.
# evidence-81826 --> Impacts from third generation
# evidence-964958 --> Thailand 's water resource per capita is less than that of other countries in the region.
# evidence-1070141 --> He began performing much less frequently, and had a presence only locally for around a decade.
# evidence-794364 --> There is one court for each Judicial District which more or less correspond with each of the 25 Regions of Peru.
# evidence-1059728 --> In general, they are volatile but less so than their parent alkanes.
# evidence-629027 --> These currently living species represent less than one percent of all species that have ever lived on earth.
# evidence-516930 --> Because of these duplications, the A6 is less important than it was formerly.
# evidence-825569 --> Scholars state that less than 25 % of the language 's original vocabulary is used today.
# evidence-790614 --> To keep warming below 2 degC, more stringent emission reductions in the near-term would allow for less rapid reductions after 2030.
# evidence-339145 --> Its water depth is less than 2 m at chart datum.
# evidence-480959 --> In 1896-97 he played against Lord Hawke 's team but had less success.
# evidence-736551 --> After an initial warming due to emissions of greenhouse gases, the atmosphere will hold more water.
# evidence-1093197 --> It is less than a kilometer away from the small hamlet of San Marcos.
# evidence-433228 --> Less than 1 % of students are listed as possessing ` limited ' English-speaking skills.
# evidence-1011437 --> For example, a small child's inhalation rate will be less than that of an adult.
# evidence-289369 --> A total of 46 clubs, 16 less than last edition, were accepted to enter.
# evidence-870399 --> Nordhaus also makes this argument, but less formally.
# evidence-40734 --> Individual dietary choices may be more or less healthy.
# evidence-911510 --> Such measures are common in Australia and Europe (especially Northern Europe), but less so in North America.
# evidence-1120967 --> (The acceleration lasted between two and three months and was less than 10% in 1996 and 1997 for example.
# evidence-868180 --> The students were inspired by the protests of May 1968 in France but used less violence.
# evidence-149691 --> He 's putting (that) at risk.
# evidence-306670 --> Despite the familiarity of the opening track, the album itself sold less than the predecessor.
# evidence-1158325 --> This makes it a District of the third class (population greater than 5,000 people less than 30,000).
# evidence-978965 --> This makes it a District of the third class (population greater than 5,000 people less than 30,000).
# evidence-1119104 --> Before 1940, more than 90 % of workers received less than US$ 7 per week.
# evidence-349948 --> The speed of the breakup is also remarkable; it took less than an hour.
# evidence-656017 --> Being further out the park is somewhat less crowded than Century Park, the largest park of the city.
# evidence-342737 --> This is much less than the fifty-two locations they had intended to visit when the Mission began.
# evidence-114074 --> The locking force is, depending on the position of the piston, more or less low.
# evidence-574136 --> The way the media report on climate change in English-speaking countries, especially in the United States, has been widely studied, while studies of reporting in other countries have been less expansive.
# evidence-948402 --> The Fifth Child is a short novel by the British writer Doris Lessing, first published in the United Kingdom in 1988, and since translated into several languages.
# evidence-228006 --> Another impact that the warming global temperature has had is on the frequency and severity of heat waves.
# evidence-1050403 --> The form Paulsen is a less common cognate.
# evidence-548766 --> Due to the increase in temperature of the soil, CO2 levels in our atmosphere increase, and as such the mean average temperature of the Earth is rising.
# evidence-115480 --> These forms of pollution have made the reef less resilient to climate change.
# evidence-111514 --> Healthy foods are also more expensive and less available in poor areas.
# evidence-255674 --> However, there are other terms with less obvious origins, which are of etymological interest.
# evidence-285338 --> The film received a less than enthusiastic review from the "New York Times", but was nominated for several awards.
# evidence-450620 --> It is usually regarded by fans as one of Magma 's less successful releases.
# evidence-1028438 --> To their great joy, the producers had adapted the seven books more or less truthfully.
# evidence-855634 --> In the scientific papers which considered climate trends of the 21st century, less than 10% inclined towards future cooling, while most papers predicted future warming.
# evidence-416075 --> Use is also not recommended in those less than three months of age and some say not less than 6 years of age.
# evidence-1045435 --> Unlike the next single, For a Rocker, it is less rock-oriented.
# evidence-1042985 --> Currently, it is less suitable for use as a kind of biodiesel than other sources.
# evidence-560338 --> Internationally famous acts as well as less known talent or locally popular musicians are represented.
# evidence-624820 --> Sambo then changed to the coxed fours, but with less success.
# evidence-937349 --> They hence appear to be suited to fire intervals of less than 20 years.
# evidence-785015 --> The remainder of the additional energy has melted ice and warmed the continents and the atmosphere.
# evidence-766232 --> Coverage for earlier in the 20th and 19th centuries would be significantly less.
# evidence-919280 --> It was less successful in the artist 's home territory of the UK, where it reached No. 5 on the UK Albums Chart.
# evidence-564383 --> Land with rock instead of fine soil are often less useful for crops.
# evidence-1140805 --> The two opposing pH levels correspond with climate change models that predict future atmospheric CO2 levels.
# evidence-1035926 --> This problem can be further exacerbated in the vicinity of industrial discharge where warm water used to cool machinery is less able to hold oxygen than the basin to which it is released.
# evidence-944837 --> Lower temperatures means less oxidation, or browning of the juice.
# evidence-1099552 --> His other most memorable moment with the Brewers had even less to do with baseball.
# evidence-903050 --> It is somewhat cooler and less luminous than our Sun.
# evidence-477195 --> Less common themes include moral instruction, and descriptions of nature.
# evidence-324448 --> The Society was less successful in attempting to preserve an Aberdeen tram.
# evidence-960902 --> Climate change will likely dramatically alter local food production capacity, which will impact those people who are more dependent on local food sources and less dependent on global or regional food supplies.
# evidence-1124246 --> Lessness Heath, a district in the London Borough of Bexley
# evidence-792345 --> Over time, these "primary" methods become less effective and "secondary" production methods may be used.
# evidence-772898 --> The victims were all less than 14 years old, and they ranged in age to as young as 8 years old.
# evidence-312751 --> It has adverse impacts on biosequestration of atmospheric carbon dioxide.
# evidence-809053 --> The party relied on powerful networks of rural elites in the less-developed parts of the country.
# evidence-457314 --> The largest contribution to total radiative forcing is caused by the increase in the atmospheric concentration of CO2 since 1750."
# evidence-700826 --> Wayne is a township in Passaic County, New Jersey, United States less than 20 mi from Midtown Manhattan.
# evidence-569617 --> After a less active period in late June and early July, activity once again picked up in late July.
# evidence-307538 --> Incorporated villages are not found in any of the other New England states, and are less common in Vermont today than they have been in the past.
# evidence-519432 --> Incorporated villages are not found in any of the other New England states, and are less common in Vermont today than they have been in the past.
# evidence-882239 --> Commercially, it was less successful than his second studio album, debuting at number 7 on the Billboard 200, with first-week sales of 54,000 copies in the United States.
# evidence-929124 --> These schemes state that cap-and-trade or "cap-and-tax" schemes inherently impact the poor and those in rural areas, who have less choice in energy consumption options.
# evidence-488203 --> In English, the plural of peninsula is peninsulas or, less commonly, peninsulae.
# evidence-967424 --> The males are less aggressive and territorial at flowers than their size would suggest.
# evidence-476621 --> They finished 9th with 70 points, just one point less than Hartlepool United in 6th, the lowest playoff position.
# evidence-172808 --> Surface-mount technology has made the technique much less useful than in previous decades.
# evidence-529451 --> It impacts regions, states and countries.
# evidence-764032 --> Entries were limited to touring cars with engines of less than eight litres.
# evidence-1186698 --> Light flyweights had to be less than 47.6 kilograms.
# evidence-972010 --> The EU produced 9% less, Africa 5% less, China 12% more, the USA 17% more.
# evidence-223826 --> Less than one crater diameter to the southwest is the prominent Werner.
# evidence-514250 --> The village of North Rauceby is less than 1 mi to the north.
# evidence-1035197 --> Being a self-pollinated species, it is less variable, and has an extended flowering season.
# evidence-449150 --> These numbers show that awareness of global warming is increasing in the United States
# evidence-364822 --> As the water vapor condenses into liquid, latent heat is released, which warms the air, causing it to become less dense than the surrounding, drier air.
# evidence-79952 --> To some extent moisture in the atmosphere accelerates the probability of a global warming event.
# evidence-359972 --> Other more or less plausible theories abound, like :
# evidence-548559 --> At the 2011 Census the population was less than 100 and is included in the civil parish of Gresham.
# evidence-547236 --> Earthquakes associated with normal faults are generally less than magnitude 7.
# evidence-962456 --> "Paleobotanical Evidence for Near Present-Day Levels of Atmospheric CO2 During Part of the Tertiary".
# evidence-149341 --> AG & AG 's events (self-defense, recreation, and practical shooting) have a girl-friendly atmosphere that can often be less intimidating to new shooters.
# evidence-611098 --> Minority interns to environmental organizations are hired less often than their white counterparts.
# evidence-734035 --> | Venting detected on site, less than 150 Ci
# evidence-152560 --> It was engaged in combat for less than a month before the 1918 Armistice with Germany.
# evidence-724295 --> Groenlo 's military history is less well known today.
# evidence-457764 --> Its length is 2.3 km and its maximum breadth less than 1 km.
# evidence-316125 --> The number of students each year used to be very low  for several decades less than 100  but has increased since the early 1990s.
# evidence-534743 --> Thus, water is about 250 times less effective of a lubricant than oil.
# evidence-454032 --> Slower currents would also mean less carbon fixation.
# evidence-274579 --> Minimum atmospheric oxygen levels in the Early Triassic are never less than present-day levels and so the decline in oxygen levels does not match the temporal pattern of the extinction.
# evidence-900964 --> Volume 6 is far less child-friendly than the other five volumes in the series.
# evidence-66273 --> Higher atmospheric CO2 concentrations have led to an increase in dissolved CO2, which causes ocean acidification.
# evidence-375992 --> Beginning in 2006, however, the fest will only screen works of 30 minutes or less.
# evidence-545304 --> The tour comprised 12 performances in six countries (USA, Denmark, Germany, Netherlands, France, United Kingdom) in venues with a capacity of 2,000 or less.
# evidence-190387 --> After leaving Bristol, Browne went on to publish no less than six more books in the final years of his retirement.
# evidence-1022951 --> St James-the-Less is a church in Bethnal Green, London, England.
# evidence-1029721 --> He became less well known in later life, and was a teacher of art at the University of Massachusetts for nearly 30 years.
# evidence-234160 --> The program 's running time (less commercial breaks) was approximately 1 hour 50 minutes.
# evidence-100449 --> Patients at the high end of the age range for a given equation require less energy.
# evidence-506171 --> Although confined to less than one-third of the globe, with a "swamp" ocean and only land surface at high latitudes, it showed an Arctic warming faster than the tropics (as have all subsequent models).
# evidence-232980 --> Thus, their national emissions budgets would be smaller than those that have polluted less in the past.
# evidence-52666 --> poor initial developmental luck for the less fortunate
# evidence-693802 --> Death is common, with 90 % to 100 % mortality, usually in less than 24 hours.
# ...
# evidence-740719 --> Reserve-Division) was a unit of the Imperial German Army in World War I.
# evidence-49357 --> He played on national basketball teams of both the United States and Israel, and served in the armies of both countries.
# evidence-825320 --> Although often apart from each other and intermixed with buffering ecosystems, the areas directly impacted by these civilisations and others were large.
# evidence-642667 --> The name ` Euroland ' is not going to be used so it will avoid the impact of price volatility in the region and as potential customers did not like the name.
# evidence-141124 --> They found that "solar effects may have contributed significantly to the warming in the first half of the century although this result is dependent on the reconstruction of total solar irradiance that is used.
# evidence-678390 --> The atmospheric signature, the Southern Oscillation (SO) reflects the monthly or seasonal fluctuations in the air pressure difference between Tahiti and Darwin.
# evidence-1152667 --> In order to maximize its impact, the organization concentrates its efforts on large states that are poised to make major decisions on energy efficiency policy issues.
# evidence-359797 --> This allowed Ptolemaic teachings on astrology to be included in universities during the Renaissance, which brought an associated impact upon medical studies and literary works.
# evidence-1047147 --> Earth science encompasses four main branches of study, the lithosphere, the hydrosphere, the atmosphere, and the biosphere, each of which is further broken down into more specialized fields.
# evidence-375981 --> Republican Congressional leadership had a difficult time distancing itself from the corruption of the Grant administration or the legislature 's impact on the economy downturn.
# evidence-749564 --> York is a city in, and the county seat of, York County, Nebraska, United States.
# evidence-820156 --> Global warming accelerates its release due to release of methane from both existing stores and methanogenesis in rotting biomass.
# evidence-916589 --> Global warming accelerates its release, due to both release of methane from existing stores, and from methanogenesis in rotting biomass.
# evidence-110432 --> Global warming boosts the probability of extreme weather events, like heat waves, far more than it boosts more moderate events.
# evidence-48758 --> New York State Department of Environmental Conservation, New York, United States
# evidence-520162 --> Florida East Coast R. Co. v. United States,
# evidence-367143 --> Miller is a city in Hand County, South Dakota, United States.
# evidence-20895 --> Category : Acts of the Parliament of the United Kingdom concerning Scotland
# evidence-218166 --> Ocean acidification is the ongoing decrease in the pH of the Earth's oceans, caused by the uptake of carbon dioxide (CO 2) from the atmosphere.
# evidence-1127174 --> His works were exhibited in the Caribbean, the United States, and Senegal.
# evidence-721134 --> Answering a question from Page on 6 May, Thatcher said that "many people are very concerned indeed that the case for our British forces is not being put over fully and effectively.
# evidence-705349 --> Later alternatives lacking the chlorine, the hydrofluorocarbons (HFCs) have an even shorter lifetimes in the lower atmosphere.
# evidence-488834 --> is a United States cartoonist and animator, and historian of comics.
# evidence-485943 --> The environmental impact of reservoirs is coming under ever increasing scrutiny as the world demand for water and energy increases and the number and size of reservoirs increases.
# evidence-259579 --> He was Ambassador of Chile to the United States from 1939 to 1942.
# evidence-445713 --> Piscataquis River, in Maine, United States
# evidence-368238 --> Tsu Chung-Chi is a relatively small lunar impact crater on the Moon 's far side.
# evidence-588934 --> Data recently made available suggest that climate impacts have already altered the circulation patterns responsible for producing and moving water vapor to the region.
# evidence-192627 --> Any info regarding DPM and the atmosphere, flora, height, and distance from major sources would be useful to determine health effects.
# evidence-1186776 --> In 2008, the Institute published a list purporting to identify "500 Scientists with Documented Doubts of Man-Made Global Warming Scares".
# evidence-1184602 --> Blair Township may refer to the following places in the United States :
# evidence-499245 --> It can be used to normalize two images, when the images were acquired at the same local illumination (such as shadows) over the same location, but by different sensors, atmospheric conditions or global illumination.
# evidence-992208 --> The model camp, made of roughly 1000 miniature tents, is a public art intervention that depicts the social impacts of climate change.
# evidence-753598 --> In fact, stabilizing emissions at current levels would result in the atmospheric concentration of CO continuing to rise over the 21st century and beyond (see the graphs opposite).
# evidence-605626 --> A study of climate records has shown that El Nino events in the equatorial Pacific are generally associated with a warm tropical North Atlantic in the following spring and summer.
# evidence-1055320 --> Regarding the persistent belief in a global warming hoax they note that the Earth is continuing to warm and the rate of warming is increasing as documented in numerous scientific studies.
# evidence-279160 --> Public opinion impacts on the issue of climate change because governments need willing electorates and citizens in order to implement policies that address climate change.
# evidence-387071 --> It was syndicated throughout Canada and the United States from 1980 to 1987.
# evidence-3910 --> American, an adjective for something of, from, or related to the United States
# evidence-947245 --> This puts him in the late 2nd century CE (Aurelius and Verus reigned from 161 to 180).
# evidence-495350 --> Liquified under pressure slightly above atmospheric, it is best known for powering cigarette lighters, but it is also a main fuel source for many developing countries.
# evidence-606994 --> | US Army Air Service, United States Army Air Forces
# evidence-356464 --> It was established on March 2, 1899 as the fifth national park in the United States.
# evidence-91685 --> For example, limiting global warming to 1.5 degC relative to pre-industrial levels reduces climate change damages more than a 2 degC limit.
# evidence-246707 --> This was a significant milestone, as Trump once tweeted that "the concept of global warming was created by and for the Chinese in order to make U.S. manufacturing non-competitive.
# evidence-89364 --> Their government was for the first time highly efficient, and the bureaucracy whom Anabwani had put in place worked far much better than previous governments.
# evidence-660662 --> The NRC was particularly critical of the program's failure to engage stakeholders or advance scientific understanding of the impacts of climate change on human well-being.
# evidence-955760 --> The urban heat island effect warms cities 0.6 to 5.6 degC (1.1 to 10.1 degF) above surrounding suburbs and rural areas.
# evidence-11680 --> Category : Populated places in Corfu (regional unit)
# evidence-374827 --> Mount Saint Michael Academy, New York City, United States
# evidence-948853 --> Drought is much more common in the West than the rest of the United States.
# evidence-101629 --> It first aired on the Fox network in the United States on February 26, 2006.
# evidence-753919 --> Sounder South Line, Washington, United States
# evidence-672723 --> Michaels has said that he does not contest the basic scientific principles behind greenhouse warming and acknowledges that the global mean temperature has increased in recent decades.
# evidence-238365 --> Hansen concluded that global warming would be evident within the next few decades, and that it would result in temperatures at least as high as during the Eemian.
# evidence-1057489 --> Computer models are run on supercomputers to reproduce and predict the circulation of the oceans, the annual cycle of the seasons, and the flows of carbon between the land surface and the atmosphere.
# evidence-932986 --> Australia's climate has warmed by more than one degree Celsius over the past century, causing an increase in the frequency and intensity of heatwaves and droughts.
# evidence-1109959 --> Coral reefs located in warm, shallow water with low water flow have been more affected than reefs located in areas with higher water flow.
# evidence-14221 --> Greater political and social freedoms, instituted by the last Soviet leader, Mikhail Gorbachev, created an atmosphere of open criticism of the communist regime.
# evidence-740392 --> He was Secretary of the United States Senate 1861-1868.
# evidence-341302 --> Described how seismic shock is transformed into the hydraulic impact within fluid-saturated fault zone.
# evidence-759723 --> They argued that the emails showed that global warming was a scientific conspiracy and that scientists manipulated climate data and attempted to suppress critics.
# evidence-1012357 --> The work as planned had three parts : the Code (Codex) is a compilation, by selection and extraction, of imperial enactments to date ; the Digest or Pandects (the Latin title contains both Digesta and Pandectae) is an encyclopedia composed of mostly brief extracts from the writings of Roman jurists ; and the Institutes (Institutiones) is a student textbook, mainly introducing the Code, although it has important conceptual elements that are less developed in the Code or the Digest.
# evidence-794328 --> He remained silent through it all, and was last seen on the evening of 27 July 1943, very weak but still conscious, being put on a truck with a guard of Japanese soldiers.
# evidence-1130557 --> From 1992 to 1993, a special field project known as the Coupled Ocean Atmosphere Research Experiment (TOGA-COARE) was conducted.
# evidence-548496 --> He largely focused his attention on the reactions of the environmental community, first at Durkin's earlier production, "Against Nature", and now at "The Great Global Warming Swindle".
# evidence-111067 --> These recent months, the village of Boufhaima, lives in connection with the installation of the East-West motorway projects, in an atmosphere of dream and imagination.
# evidence-599141 --> Phytoplankton concentrations in surface waters were estimated to have decreased by about 40% since 1950, at a rate of around 1% per year, possibly in response to ocean warming.
# evidence-867907 --> The album was released by Epic Records in the United States on November 9, 1999.
# evidence-941644 --> However, aside from the simple cold gas thruster and steam rocket, none has yet been put to practical use.
# evidence-1009945 --> Category :3 ft gauge railways in the United States
# evidence-923350 --> The museum also owns 4 kilometres of low-impact nature trails in its Theodore Fouriezos Wetlands Park.
# evidence-1110240 --> The race began in 1963 as a part of the United States Road Racing Championship.
# evidence-1183671 --> This was in line with Indecision Records tradition of putting out releases by new bands on colored and normal vinyl and was carried through to their next release, the Fall from Grace (EP).
# evidence-698012 --> In the United Kingdom, Science Diet is known as Science Plan.
# evidence-91103 --> Thunderstorm  also electrical storm, form of weather characterized by the presence of lightning and its acoustic effect on the Earth 's atmosphere known as thunder.
# evidence-642267 --> It went on to sell 350,000 in the United Kingdom.
# evidence-545548 --> It shines with a luminosity over 900 times that of the Sun from a relatively cool outer atmosphere that has an effective temperature of 3,756.
# evidence-702017 --> Upwelling radiance is measured at different frequencies; these different frequency bands sample a different weighted range of the atmosphere.
# evidence-998675 --> was first seen on November 3, 2001 on ABC Family in the United States.
# evidence-996197 --> It was invented in the United States by Philip Bryant.
# evidence-1033718 --> Other fees by government are possible for improvements such as curbs and sidewalks or an impact fee for building a house on a vacant lot.
# evidence-1150990 --> Magazine is a city in Logan County, Arkansas, United States.
# evidence-550631 --> Category : Defunct semiconductor companies of the United States
# evidence-458543 --> Besides the immediate impact on the victims and their families, the attacks caused widespread anger among the Indian public, and condemnations from countries throughout the world.
# evidence-232769 --> It originally aired on the Fox network in the United States on May 5, 1996.
# evidence-954510 --> It currently has a membership of over 1200, primarily in the United States.
# evidence-450353 --> Bandy in the United States is played mostly in Minnesota.
# evidence-978268 --> Many other programs have been put in place to help farmer finances and debt such as Agricultural Extension Services, public works programs, and unconditional cash transfers.
# evidence-814109 --> , a gunboat in the United States Navy during the American Civil War.
# evidence-391544 --> In 2015, 32 percent or Americans were worried about global warming as a great deal, 37 percent in 2016, and 45 percent in 2017.
# evidence-1036899 --> It reached the top 20 in the United Kingdom, the Netherlands, and New Zealand.
# evidence-74806 --> The Climate Vulnerable Forum (CVF) is a global partnership of countries that are disproportionately affected by the consequences of global warming.
# evidence-903114 --> The picture is notable for its pervasive atmosphere of dread and the innovative decision to depict the beast as a bird-like creature.
# evidence-270942 --> Namazi played a handful of games with the Hershey Impact of the American Indoor Soccer Association during the 1989-1990 season before being released on January 13, 1990.
# evidence-41147 --> They are found in the Americas from the Southwestern United States to Southeastern Brazil.
# evidence-1072857 --> It is the largest event celebrating African-American culture and music in the United States.
# evidence-905473 --> In the United Kingdom, two versions of the song went to number one in 1955.
# evidence-1145839 --> From 1938 Guy Stewart Callendar published evidence that climate was warming and levels increasing, but his calculations met the same objections.
# evidence-814678 --> Inside of this ice there are traces of bubbles that are filled with CO that are then released into the atmosphere when they melt causing the greenhouse effect to grow at an even faster rate.
# evidence-460341 --> In 1939, the region of Jabal Sinjar was once again put under military control, together with the Shekhan District.
# evidence-929435 --> The grass is a federally listed endangered species of the United States.
# evidence-180923 --> They also found that the warming during the 10-14th centuries in some regions might be comparable in magnitude to the warming of the last few decades of the 20th century, which was unprecedented within the past 500 years.
# evidence-432181 --> Conservationists sought to regulate human use while preservationists sought to eliminate human impact altogether.
# evidence-66197 --> Originally released on his 1964 debut album, All the News That 's Fit to Sing, Power and the Glory is said to have contributed to Ochs ' profound impact.
# evidence-375825 --> Canada won the title for the second time after defeating United States 3  0 in the final.
# evidence-517669 --> She was the only ship of the United States Navy to be named for Orlando, Florida.
# evidence-310687 --> Act 2006 (c 27) is an Act of the Parliament of the United Kingdom.
# evidence-947016 --> 35th Signal Battalion (United States)
#
# Matching evidence passages: {'evidence-178206', 'evidence-1099186', 'evidence-1169593'}
# Precision: 0.0003, Recall: 0.6, F1: 0.0005997001499250374
# (0.0003, 0.6, 0.0005997001499250374)

# %% [markdown]
# #### Compute the following retreiver evaluation metrics on Validation Claims: Average Precision, Average Recall, Average F1 score

# %%
# retreival performance on entire validation set
k_values = [3, 5, 8, 10, 15, 25, 50, 100, 250, 500, 1000, 2000, 5000]
avg_precision, avg_recall, avg_f1 = eval(val_data.values(), int2docID, retriever, k_values=k_values)

for i in range(len(k_values)):
    print(f"k = {k_values[i]} --> Average Precision: {avg_precision[i]}, Average Recall: {avg_recall[i]}, Average F1: {avg_f1[i]}")
# Out:
# 100%|██████████| 154/154 [01:20<00:00,  1.92it/s]
# k = 3 --> Average Precision: 0.08658008658008662, Average Recall: 0.10606060606060608, Average F1: 0.08718305504019791
# k = 5 --> Average Precision: 0.06883116883116881, Average Recall: 0.13495670995670989, Average F1: 0.08442589156874873
# k = 8 --> Average Precision: 0.05925324675324675, Average Recall: 0.17965367965367957, Average F1: 0.08372839281930185
# k = 10 --> Average Precision: 0.05194805194805192, Average Recall: 0.19080086580086572, Average F1: 0.07738279036980335
# k = 15 --> Average Precision: 0.04025974025974026, Average Recall: 0.21428571428571414, Average F1: 0.0651972511492635
# k = 25 --> Average Precision: 0.03116883116883119, Average Recall: 0.27370129870129867, Average F1: 0.05456875727811688
# k = 50 --> Average Precision: 0.02064935064935066, Average Recall: 0.36991341991342, Average F1: 0.03854835769879658
# k = 100 --> Average Precision: 0.013311688311688316, Average Recall: 0.4522727272727274, Average F1: 0.025672520100214258
# k = 250 --> Average Precision: 0.006883116883116888, Average Recall: 0.5595238095238095, Average F1: 0.013557877248429807
# k = 500 --> Average Precision: 0.003922077922077925, Average Recall: 0.6296536796536797, Average F1: 0.007783949006356322
# k = 1000 --> Average Precision: 0.002214285714285716, Average Recall: 0.7030303030303029, Average F1: 0.004411360526727808
# k = 2000 --> Average Precision: 0.0012207792207792217, Average Recall: 0.7756493506493505, Average F1: 0.0024368187247838942
# k = 5000 --> Average Precision: 0.0005493506493506495, Average Recall: 0.8746753246753246, Average F1: 0.001097844382171683

# %% [markdown]
# #### Compute the following retreiver evaluation metrics on Training Claims: Average Precision, Average Recall, Average F1 score

# %%
"""# retreival performance on entire training set
k_values = [3, 5, 8, 10, 15, 25, 50, 100, 250, 500, 1000, 2000, 5000]
avg_precision, avg_recall, avg_f1 = eval(train_data.values(), int2docID, retriever, k_values=k_values)

for i in range(len(k_values)):
    print(f"k = {k_values[i]} --> Average Precision: {avg_precision[i]}, Average Recall: {avg_recall[i]}, Average F1: {avg_f1[i]}")"""
# Out:
# '# retreival performance on entire training set\nk_values = [3, 5, 8, 10, 15, 25, 50, 100, 250, 500, 1000, 2000, 5000]\navg_precision, avg_recall, avg_f1 = eval(train_data.values(), int2docID, bm25, k_values=k_values)\n\nfor i in range(len(k_values)):\n    print(f"k = {k_values[i]} --> Average Precision: {avg_precision[i]}, Average Recall: {avg_recall[i]}, Average F1: {avg_f1[i]}")'

# %% [markdown]
# ### **Query Expansion**:
#
# We will now try out Query Expansion techniques to see if we can further improve the performance of the BM25 retriever. We will try the following techniques:
#
#     1) Queries are paraphrased using BackTranlsation
#     2) Queries are paraphrased using Synonym Substitution

# %%
from tqdm import tqdm
import pickle 
import random

import nltk
from nltk.tokenize import word_tokenize
from nltk.wsd import lesk
from nltk.corpus import stopwords

import spacy

import torch
import warnings
warnings.filterwarnings("ignore")

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %% [markdown]
# #### Define a sentence augmenter class that generates the sentence paraphrases.

# %%
# give me a sentence augmentor class combining all three augmentor types that I explore earlier

class SentenceAugmentor:
    def __init__(self, syn_sub_prob=0.25, forward_temperature=1.5, backward_temperature=3.0, num_beams=5, num_return_sequences=2, syn_sub=True, backtranslation=True, named_ents = True):

        self.syn_sub_prob = syn_sub_prob   
        self.forward_temperature = forward_temperature
        self.backward_temperature = backward_temperature
        self.num_beams = num_beams
        self.num_return_sequences = num_return_sequences
        self.backtranslation = backtranslation
        self.syn_sub = syn_sub
        self.named_ents = named_ents

        if backtranslation:    
            # backtranslation models
            self.model_en_fr = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-fr")
            self.tokenizer_en_fr = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-fr")
            self.tokenizer_fr_en = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-fr-en")
            self.model_fr_en = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-fr-en")

        if syn_sub:
            self.stop_words = set(stopwords.words('english'))

        if named_ents:
            self.nlp = spacy.load('en_core_web_lg')

 
    def synonym_substitution(self, text_batch):
        output_batch = []
        for sentence in text_batch:
            words = word_tokenize(sentence)
            new_words = []
            for word in words:
                if word.lower() not in self.stop_words:
                    synset = lesk(words, word)
                    if synset is not None:
                        synonyms = synset.lemma_names()
                        if synonyms and random.random() < self.syn_sub_prob:
                            new_word = random.choice(synonyms)  # choose a random synonym
                            new_words.append(new_word.replace('_', ' '))
                        else:
                            new_words.append(word)
                    else:
                        new_words.append(word)
                else:
                    new_words.append(word)
            sentence_syn =  [" ".join(new_words)]
            output_batch.append(sentence_syn)
        
        return output_batch    

    def translate(self, text_batch, model, tokenizer, temperature=None, num_beams=10, num_return_sequences=3, verbose=False):
        if verbose: print(f"Translation input --> {text_batch}")
        # Prepare the text input
        #inputs = tokenizer.encode(text, return_tensors="pt")
        inputs = tokenizer(text_batch, return_tensors="pt", padding=True, truncation=True)['input_ids']
        # Generate the translated text
        if temperature is None:
            # Always choosing the most probable word
            outputs = model.generate(inputs, max_length=128, do_sample=False, num_beams=num_beams, num_return_sequences=num_return_sequences, early_stopping=True)
        else:    
            # Using temperature-based sampling
            outputs = model.generate(inputs, max_length=128, do_sample=True, temperature=temperature, num_beams=num_beams, num_return_sequences=num_return_sequences, early_stopping=True)

        #translated_texts =  tokenizer.decode(outputs, skip_special_tokens=True)
        translated_texts =  tokenizer.batch_decode (outputs, skip_special_tokens=True)

        if verbose: 
            for i, t in enumerate(translated_texts):
                print(f"\tBeam {i+1} --> {t}") 
        
        return translated_texts


    def back_translate(self, text_batch, verbose=False):
        if verbose: print(f"Original sentence --> {text_batch}")

        # Translate the text to French
        if verbose: print(f"Translating to french...")
        french_texts = self.translate(text_batch, self.model_en_fr, self.tokenizer_en_fr, temperature=self.forward_temperature, num_beams=self.num_beams, num_return_sequences=self.num_return_sequences, verbose=verbose)

        if verbose: print(f"Translating to english...")
        backtranslation_output = self.translate(french_texts, self.model_fr_en, self.tokenizer_fr_en, temperature=self.backward_temperature, num_beams=self.num_beams, num_return_sequences=self.num_return_sequences, verbose=verbose)

        # reshape sentence list to nested list
        backtranslation_output = [backtranslation_output[i:i+self.num_return_sequences*self.num_return_sequences] for i in range(0, len(backtranslation_output), self.num_return_sequences*self.num_return_sequences)]

        return backtranslation_output


    def append_named_ents(self, sentences):
        sentences_with_ent = []
        for s in sentences:
            doc = self.nlp(s)
            named_entities = [ent.text for ent in doc.ents]
            # append entities to sentence
            sentences_with_ent.append([s + " " + " ".join(named_entities)])    
        
        return sentences_with_ent


    def augment(self, sentences):

        if self.named_ents:
            output_ents = self.append_named_ents(sentences)

        if self.syn_sub:   
            output_syn = self.synonym_substitution(sentences)
        
        # combine augmented sentences per batch item
        if self.backtranslation:
            output_backtranslation = self.back_translate(sentences)

        augmented_sentences = []
        for i in range(len(sentences)):
            aug_s = []
            if self.named_ents:
                aug_s += output_ents[i]
            if self.syn_sub:
                aug_s += output_syn[i]
            if self.backtranslation:
                aug_s += output_backtranslation[i]    
            augmented_sentences.append(aug_s)
        
        return augmented_sentences


def augmented_eval(claims_dataset, bm25, augmenter=None, k_values=[10], keep_query=True):
    
    k_values = sorted(k_values)
    precision = np.zeros(len(k_values))
    recall = np.zeros(len(k_values))
    f1 = np.zeros(len(k_values))

    for claim in tqdm(claims_dataset.values(), total=len(claims_dataset)):
        query = claim["claim_text"]
        gold_evidence_list = claim["evidences"]

        if augmenter is not None:
            # expand the query
            expanded_query = augmenter.augment([query])[0]
            #print(f"Expanded query: {expanded_query}")
            # clean the expanded queries
            for i in range(len(expanded_query)):
                expanded_query[i] = cleaner.clean(expanded_query[i])
            if keep_query:
                expanded_query.append(query)
                
        else:
            expanded_query = [query]


        # retrieve bm25 topk documents for each expanded query and combine them
        topk_ev_indices = []
        for q in expanded_query:
            topk_ev_idx, topk_scores = bm25.retrieve_docs(q, topk=max(k_values))
            topk_ev_indices.append(topk_ev_idx)
        
        # Interlacing selection
        interlaced_indices = [idx for sublist in zip(*topk_ev_indices) for idx in sublist]
        # remove duplicates
        interlaced_indices = list(dict.fromkeys(interlaced_indices))
        # Truncate to max k_values
        interlaced_indices = interlaced_indices[:max(k_values)]
        topk_ev_indices = interlaced_indices

        #else:
        #    topk_ev_indices, best_scores = bm25.retrieve_docs(query, topk=max(k_values))

        if topk_ev_indices == []:
            continue
        # convert document indices to document id strings
        topk_ev_ids_bm25 = [int2docID[i] for i in topk_ev_indices]

        for i, k in enumerate(k_values):
            # (precision, recall, F1) for bm25
            intersection = set(topk_ev_ids_bm25[:k]).intersection(gold_evidence_list)
            p = len(intersection) / len(topk_ev_ids_bm25[:k])
            r = len(intersection) / len(gold_evidence_list)
            precision[i] += p
            recall[i] += r
            f1[i] += (2*p*r/(p + r)) if (p+r) > 0 else 0

    # average over all claims
    precision = precision / len(claims_dataset) 
    recall = recall / len(claims_dataset)
    f1 = f1 / len(claims_dataset)

    # convert to dictionary
    metrics = {k:{"precision":precision[i], "recall":recall[i], "f1":f1[i]} for i,k in enumerate(k_values)}

    return metrics

# %% [markdown]
# #### Try out some different hyperparameter combinations of the sentence augmenter and evaluate BM25 performance on Validation Claims.
#
# best setting found --> `SentenceAugmentor(forward_temperature=1.5, backward_temperature=3.0, num_beams=5, num_return_sequences=2, syn_sub=False, backtranslation=True, backward_temperature=2.0)`
#
# Best setting only gives ~1% increase in average F1 score. Not impressive.

# %%
# create augmenter
augmenter = SentenceAugmentor(num_return_sequences=2, syn_sub=False, backtranslation=True, backward_temperature=2.0)

k_values = [3, 5, 8, 10, 15, 25, 50, 100, 250, 500]

metrics = augmented_eval(val_data, retriever, augmenter, k_values)

for k, k_metrics in metrics.items():
    print(f"k = {k} --> P = {k_metrics['precision']}, R = {k_metrics['recall']}, F = {k_metrics['f1']}")
# Out:
# 100%|██████████| 154/154 [05:58<00:00,  2.33s/it]
# k = 3 --> P = 0.09307359307359314, R = 0.11114718614718615, F = 0.09301175015460733
# k = 5 --> P = 0.0701298701298701, R = 0.13051948051948048, F = 0.0848072562358277
# k = 8 --> P = 0.05194805194805195, R = 0.15573593073593064, F = 0.07312939585666856
# k = 10 --> P = 0.04675324675324672, R = 0.16893939393939383, F = 0.06931856022765115
# k = 15 --> P = 0.03896103896103896, R = 0.2066017316017315, F = 0.06292642256264545
# k = 25 --> P = 0.027792207792207813, R = 0.24329004329004317, F = 0.04855350815941949
# k = 50 --> P = 0.019610389610389627, R = 0.34502164502164506, F = 0.03660849048297336
# k = 100 --> P = 0.012402597402597412, R = 0.42543290043290044, F = 0.023923965426800316
# k = 250 --> P = 0.006753246753246758, R = 0.564935064935065, F = 0.013306263073692566
# k = 500 --> P = 0.003922077922077925, R = 0.6385281385281385, F = 0.007784512524778234

# %%
# create augmenter
augmenter = SentenceAugmentor(num_beams=10, num_return_sequences=3, syn_sub=False, backtranslation=True, backward_temperature=2.0)

k_values = [3, 5, 8, 10, 15, 25, 50, 100, 250, 500]

metrics = augmented_eval(val_data, retriever, augmenter, k_values)

for k, k_metrics in metrics.items():
    print(f"k = {k} --> P = {k_metrics['precision']}, R = {k_metrics['recall']}, F = {k_metrics['f1']}")
# Out:
# 100%|██████████| 154/154 [10:38<00:00,  4.15s/it]
# k = 3 --> P = 0.08874458874458882, R = 0.09924242424242426, F = 0.08695114409400127
# k = 5 --> P = 0.06753246753246751, R = 0.12987012987012986, F = 0.08276643990929708
# k = 8 --> P = 0.05438311688311688, R = 0.1651515151515151, F = 0.07694224966952237
# k = 10 --> P = 0.04675324675324672, R = 0.1742424242424242, F = 0.06989655366278744
# k = 15 --> P = 0.03852813852813854, R = 0.2103896103896103, F = 0.06261258091753444
# k = 25 --> P = 0.02909090909090911, R = 0.25454545454545446, F = 0.05084513187961464
# k = 50 --> P = 0.019610389610389627, R = 0.34134199134199134, F = 0.03658141000992376
# k = 100 --> P = 0.01266233766233767, R = 0.4386363636363636, F = 0.024430835320934874
# k = 250 --> P = 0.006987012987012992, R = 0.5676406926406926, F = 0.013763003422246652
# k = 500 --> P = 0.004038961038961042, R = 0.6467532467532469, F = 0.008015963424980014

# %%
# create augmenter
augmenter = SentenceAugmentor(num_beams=20, num_return_sequences=3, syn_sub=False, backtranslation=True, backward_temperature=2.0)

k_values = [3, 5, 8, 10, 15, 25, 50, 100, 250, 500]

metrics = augmented_eval(val_data, retriever, augmenter, k_values)

for k, k_metrics in metrics.items():
    print(f"k = {k} --> P = {k_metrics['precision']}, R = {k_metrics['recall']}, F = {k_metrics['f1']}")
# Out:
# 100%|██████████| 154/154 [12:15<00:00,  4.77s/it]
# k = 3 --> P = 0.08874458874458879, R = 0.10757575757575757, F = 0.08888373531230677
# k = 5 --> P = 0.06623376623376621, R = 0.12380952380952376, F = 0.08002989074417648
# k = 8 --> P = 0.060876623376623376, R = 0.17900432900432892, F = 0.0855820946730037
# k = 10 --> P = 0.053246753246753195, R = 0.19696969696969685, F = 0.07948544961531971
# k = 15 --> P = 0.04112554112554112, R = 0.22196969696969684, F = 0.06659440490709836
# k = 25 --> P = 0.03090909090909093, R = 0.2649350649350649, F = 0.053949954442565284
# k = 50 --> P = 0.02103896103896105, R = 0.3724025974025974, F = 0.03924765522485226
# k = 100 --> P = 0.013506493506493513, R = 0.46049783549783563, F = 0.02604362657064405
# k = 250 --> P = 0.007116883116883122, R = 0.5852813852813852, F = 0.014019277174507969
# k = 500 --> P = 0.0040779220779220806, R = 0.6596320346320348, F = 0.008093371163300037

# %%
# create augmenter
augmenter = SentenceAugmentor(num_beams=10, num_return_sequences=3, syn_sub=False, backtranslation=True, backward_temperature=2.0, named_ents=True)

k_values = [3, 5, 8, 10, 15, 25, 50, 100, 250, 500]

metrics = augmented_eval(val_data, retriever, augmenter, k_values, keep_query=False)

for k, k_metrics in metrics.items():
    print(f"k = {k} --> P = {k_metrics['precision']}, R = {k_metrics['recall']}, F = {k_metrics['f1']}")
# Out:
# 100%|██████████| 154/154 [09:58<00:00,  3.88s/it]
# k = 3 --> P = 0.08658008658008663, R = 0.09512987012987016, F = 0.08381261595547312
# k = 5 --> P = 0.06753246753246751, R = 0.12673160173160167, F = 0.08174087816944962
# k = 8 --> P = 0.05194805194805195, R = 0.15216450216450209, F = 0.07290184562911833
# k = 10 --> P = 0.04805194805194802, R = 0.17056277056277047, F = 0.07123006863266605
# k = 15 --> P = 0.03766233766233768, R = 0.201082251082251, F = 0.061011039184413765
# k = 25 --> P = 0.02935064935064937, R = 0.2515151515151514, F = 0.0512423537054079
# k = 50 --> P = 0.020259740259740273, R = 0.36309523809523814, F = 0.037808871024490015
# k = 100 --> P = 0.012337662337662345, R = 0.42500000000000004, F = 0.02379435831177287
# k = 250 --> P = 0.0068311688311688355, R = 0.5630952380952381, F = 0.013458037742119048
# k = 500 --> P = 0.003974025974025977, R = 0.6423160173160174, F = 0.00788727749637498

# %%
k_values = [3, 5, 8, 10, 15, 25, 50, 100, 250, 500]
metrics = augmented_eval(val_data, retriever, None, k_values)

for k, k_metrics in metrics.items():
    print(f"k = {k} --> P = {k_metrics['precision']}, R = {k_metrics['recall']}, F = {k_metrics['f1']}")
# Out:
#   0%|          | 0/154 [00:00<?, ?it/s]
# 100%|██████████| 154/154 [00:35<00:00,  4.36it/s]
# k = 3 --> P = 0.08658008658008662, R = 0.10660173160173161, F = 0.0874922696351268
# k = 5 --> P = 0.0701298701298701, R = 0.13571428571428565, F = 0.08554421768707485
# k = 8 --> P = 0.05925324675324675, R = 0.17878787878787872, F = 0.08354675627402894
# k = 10 --> P = 0.05194805194805191, R = 0.1908008658008657, F = 0.07738279036980335
# k = 15 --> P = 0.04025974025974026, R = 0.21536796536796526, F = 0.06523969236817531
# k = 25 --> P = 0.03194805194805197, R = 0.27846320346320347, F = 0.05589838003631106
# k = 50 --> P = 0.020909090909090922, R = 0.3703463203463204, F = 0.03902042792164877
# k = 100 --> P = 0.012922077922077932, R = 0.43636363636363645, F = 0.024914664510425892
# k = 250 --> P = 0.006779220779220784, R = 0.5534632034632035, F = 0.013353756793204954
# k = 500 --> P = 0.0039090909090909115, R = 0.632900432900433, F = 0.0077583354221456464
